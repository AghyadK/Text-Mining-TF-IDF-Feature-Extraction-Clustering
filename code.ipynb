# %% [markdown]
# # The data

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
import nltk
import sklearn.cluster as clustering
from sklearn.metrics.cluster import normalized_mutual_info_score as NMI

pd.options.display.float_format = '{:,.2f}'.format

# nltk.download('punkt') # Uncomment if needed when running
# nltk.download('words')

# %%
data_path = 'abstractdata5.csv'
original_data = pd.read_csv(data_path, sep='#', names=['id', 'class', 'title' ,'abstract'], index_col='id')
data = original_data.copy()
data['text'] = original_data[['title', 'abstract']].agg(' '.join, axis=1)
snow = nltk.stem.SnowballStemmer('english')
data['cleaned'] = data['text'].map(lambda sentence: ' '.join([snow.stem(w) for w in nltk.word_tokenize(sentence)]))
vectorizer = TfidfVectorizer(stop_words='english')
tfidf = vectorizer.fit_transform(data['cleaned'])
vectorizer.get_feature_names_out().shape
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(tfidf)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.7075916942964255

# %%
y_pred = clustering.AffinityPropagation().fit_predict(tfidf.toarray())
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# /home/meek/.local/lib/python3.8/site-packages/sklearn/cluster/_affinity_propagation.py:250: ConvergenceWarning: Affinity propagation did not converge, this model will not have any cluster centers.
#   warnings.warn(
# 0.0

# %%
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
tfidf = vectorizer.fit_transform(data['cleaned'])
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(tfidf)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.7174609625369943

# %%
from sklearn import decomposition
reduction = decomposition.PCA(n_components=100).fit_transform(tfidf.toarray())

# %%
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(reduction)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.7344767423266741

# %%
reduction = decomposition.PCA(n_components=150, random_state=0).fit_transform(tfidf.toarray())
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(reduction)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.7373157011200171

# %%
res = {'spectral':{}, 'kmeans': {}}
#for i in range(5, 300, 5):
#    reduction = decomposition.PCA(n_components=i, random_state=0).fit_transform(tfidf.toarray())
#    y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(reduction)
#    res['spectral'][i] = NMI(y_pred, data['class'], average_method='geometric')
#    y_pred = clustering.SpectralClustering(n_clusters=5, random_state=0).fit_predict(reduction)
#    res['kmeans'][i] = NMI(y_pred, data['class'], average_method='geometric')
#    print(i, ':', res['kmeans'][i], ':', res['spectral'][i])

# %%
reduction = decomposition.PCA(n_components=240, random_state=0).fit_transform(tfidf.toarray())
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(reduction)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.7533063134626479

# %%
from collections import Counter as count
content = {}
for i in range(0,4):
    content[i] = count(vectorizer.get_feature_names_out()[tfidf.toarray()[y_pred==i].argmax(axis=1)]).most_common()

# %%
words = set(nltk.corpus.words.words())
data['english'] = data['text'].map(lambda sentence: 
                                   ' '.join([snow.stem(w) for w in nltk.wordpunct_tokenize(sentence) if w in words]))
vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1,2))
tfidf = vectorizer.fit_transform(data['english'])
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(tfidf)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.4680857822460559

# %%
data['english'] = data['text'].map(lambda sentence: 
                                   ' '.join([w for w in nltk.word_tokenize(sentence)]))
vectorizer = TfidfVectorizer(stop_words='english')
tfidf = vectorizer.fit_transform(data['english'])
y_pred = clustering.KMeans(n_clusters=5, random_state=0).fit_predict(tfidf)
NMI(y_pred, data['class'], average_method='geometric')
# Out:
# 0.578530660049897

# %%
content
# Out:
# {0: [('quantum', 8),
#   ('regist', 6),
#   ('schedul', 6),
#   ('queue', 4),
#   ('loop', 4),
#   ('teach', 4),
#   ('gate', 3),
#   ('qualifi', 3),
#   ('memori model', 3),
#   ('code', 3),
#   ('offload', 2),
#   ('instruct', 2),
#   ('ti', 2),
#   ('mpi', 2),
#   ('transform rule', 2),
#   ('graph color', 2),
#   ('simd', 2),
#   ('effect', 2),
#   ('proof', 2),
#   ('spm', 2),
#   ('phoa', 2),
#   ('concurr', 2),
#   ('noc', 2),
#   ('circuit', 2),
#   ('run tim', 2),
#   ('polyhedr', 1),
#   ('check', 1),
#   ('flow', 1),
#   ('sqram', 1),
#   ('picco', 1),
#   ('cobalt', 1),
#   ('rpc', 1),
#   ('transform', 1),
#   ('hybrid flow', 1),
#   ('layout', 1),
#   ('parallel', 1),
#   ('grammar', 1),
#   ('mcds', 1),
#   ('ic', 1),
#   ('visual comput', 1),
#   ('gel', 1),
#   ('fsc', 1),
#   ('lr', 1),
#   ('quantum anneal', 1),
#   ('defacto', 1),
#   ('decompress', 1),
#   ('interv graph', 1),
#   ('pim', 1),
#   ('focus', 1),
#   ('execut', 1),
#   ('languag', 1),
#   ('emul', 1),
#   ('reaction', 1),
#   ('secur parti', 1),
#   ('obfusc', 1),
#   ('cuda', 1),
#   ('mpc', 1),
#   ('argument', 1),
#   ('qubit', 1),
#   ('rf', 1),
#   ('represent space', 1),
#   ('student', 1),
#   ('heterogen', 1),
#   ('ipo', 1),
#   ('random walk', 1),
#   ('tier', 1),
#   ('game', 1),
#   ('quadrat', 1),
#   ('color', 1),
#   ('plcc', 1),
#   ('window', 1),
#   ('pvs', 1),
#   ('verif compil', 1),
#   ('toolset', 1),
#   ('overhead', 1),
#   ('mathemat reason', 1),
#   ('channel', 1),
#   ('zolb', 1),
#   ('matric', 1),
#   ('cellular nonlinear', 1),
#   ('memori bank', 1),
#   ('queuecor', 1),
#   ('numer', 1),
#   ('synthesi', 1),
#   ('certifi', 1),
#   ('heterogen hardwar', 1),
#   ('defin float', 1),
#   ('optimus', 1),
#   ('constraint network', 1),
#   ('checker', 1),
#   ('graph', 1),
#   ('parti comput', 1),
#   ('ctl', 1),
#   ('comput model', 1),
#   ('compil test', 1),
#   ('stc', 1),
#   ('ssi', 1),
#   ('solver', 1),
#   ('floating', 1),
#   ('asynchron', 1),
#   ('ershov', 1),
#   ('intern model', 1),
#   ('crosstalk', 1),
#   ('data plane', 1),
#   ('migrat', 1),
#   ('algorithm averag', 1),
#   ('memori space', 1),
#   ('œuf', 1),
#   ('cor', 1),
#   ('restart', 1),
#   ('equival', 1),
#   ('np', 1),
#   ('hardwar configur', 1),
#   ('compcert', 1),
#   ('general purpos', 1),
#   ('data depend', 1),
#   ('adl', 1),
#   ('linear algebra', 1),
#   ('metatheori', 1),
#   ('rang analysi', 1),
#   ('construct principl', 1),
#   ('verifi', 1),
#   ('prioriti', 1),
#   ('instruct instanc', 1),
#   ('gpu', 1),
#   ('cluster', 1),
#   ('regex', 1),
#   ('io2bo', 1),
#   ('logic framework', 1),
#   ('divcon', 1),
#   ('mddg', 1),
#   ('quarc', 1),
#   ('dvs', 1),
#   ('load flow', 1),
#   ('asip', 1),
#   ('ada', 1),
#   ('single qubit', 1),
#   ('communic set', 1),
#   ('poet', 1),
#   ('lego', 1),
#   ('matchingref', 1),
#   ('partial replic', 1),
#   ('sram', 1),
#   ('verifi softwar', 1),
#   ('energi effici', 1),
#   ('adapt', 1),
#   ('tpfosss', 1),
#   ('conform check', 1),
#   ('measur', 1),
#   ('regular express', 1),
#   ('curri', 1),
#   ('block', 1),
#   ('clock', 1),
#   ('adc', 1),
#   ('bit', 1),
#   ('simul', 1),
#   ('templat', 1),
#   ('communic complex', 1),
#   ('coverag', 1),
#   ('javacc', 1),
#   ('comput cryptographi', 1),
#   ('xacc', 1),
#   ('mind', 1),
#   ('cpu gpu', 1),
#   ('pdca', 1),
#   ('distanc memori', 1),
#   ('transmon', 1),
#   ('itre', 1),
#   ('thunk', 1),
#   ('free', 1),
#   ('specif languag', 1),
#   ('fpgas', 1),
#   ('dynam integr', 1),
#   ('flow graph', 1),
#   ('vertex', 1),
#   ('iter', 1),
#   ('grid', 1),
#   ('precompil', 1),
#   ('soft processor', 1),
#   ('conceptu knowledg', 1),
#   ('repair', 1),
#   ('librari', 1),
#   ('vanhels', 1),
#   ('program represent', 1),
#   ('omni', 1),
#   ('echo', 1),
#   ('flow inform', 1),
#   ('slice', 1),
#   ('sike', 1),
#   ('verif', 1),
#   ('compil develop', 1),
#   ('transact', 1),
#   ('intuitionist', 1),
#   ('miss', 1),
#   ('wire', 1),
#   ('cours', 1),
#   ('implement obtain', 1),
#   ('languag processor', 1),
#   ('decomposit', 1),
#   ('ocl', 1),
#   ('maritim communic', 1),
#   ('hmmer', 1),
#   ('quasi invari', 1),
#   ('flowgsp', 1),
#   ('reconfigur', 1),
#   ('checkpoint', 1),
#   ('auxiliari variabl', 1),
#   ('tutor', 1),
#   ('memori', 1),
#   ('garbag', 1),
#   ('datalog', 1),
#   ('live', 1),
#   ('ir', 1),
#   ('byte code', 1)],
#  1: [('quantum', 10),
#   ('chaotic', 7),
#   ('iot', 6),
#   ('encrypt', 6),
#   ('secur', 5),
#   ('cloud', 5),
#   ('attack', 3),
#   ('authent', 3),
#   ('signatur', 3),
#   ('protocol', 3),
#   ('card', 3),
#   ('multipli', 2),
#   ('healthcar', 2),
#   ('share', 2),
#   ('certificateless', 2),
#   ('ascon', 2),
#   ('devic', 2),
#   ('box', 2),
#   ('fault', 2),
#   ('privaci', 2),
#   ('dna', 2),
#   ('vcs', 2),
#   ('lattice', 2),
#   ('steganographi', 2),
#   ('mpsi', 1),
#   ('traffic', 1),
#   ('ess', 1),
#   ('septupl', 1),
#   ('azimuth', 1),
#   ('ae', 1),
#   ('fault analysi', 1),
#   ('random number', 1),
#   ('vehicular', 1),
#   ('nc1', 1),
#   ('dfcs', 1),
#   ('display', 1),
#   ('signatur scheme', 1),
#   ('hyperjerk', 1),
#   ('meter', 1),
#   ('dilithium', 1),
#   ('wban', 1),
#   ('attribute bas', 1),
#   ('tverski index', 1),
#   ('ed448', 1),
#   ('lfsr', 1),
#   ('smart citi', 1),
#   ('ellipt curv', 1),
#   ('rfid', 1),
#   ('reusabl key', 1),
#   ('nj', 1),
#   ('visual cryptographi', 1),
#   ('homomorph', 1),
#   ('anomali', 1),
#   ('ehr', 1),
#   ('architectur', 1),
#   ('microarchitectur', 1),
#   ('dsqc', 1),
#   ('gea', 1),
#   ('trng prng', 1),
#   ('cipher', 1),
#   ('medic', 1),
#   ('brlwe', 1),
#   ('shor algorithm', 1),
#   ('catalan', 1),
#   ('aerial communic', 1),
#   ('lora', 1),
#   ('shuffl', 1),
#   ('optic hash', 1),
#   ('signal', 1),
#   ('resourc constrain', 1),
#   ('cryptographi standard', 1),
#   ('tunnel', 1),
#   ('payment', 1),
#   ('spma', 1),
#   ('digit', 1),
#   ('particip attack', 1),
#   ('commerc', 1),
#   ('crystals kyb', 1),
#   ('cryptoverif', 1),
#   ('liga', 1),
#   ('healthcar wireless', 1),
#   ('kem', 1),
#   ('ecc', 1),
#   ('bitplan', 1),
#   ('home', 1),
#   ('channel', 1),
#   ('abe', 1),
#   ('encod scheme', 1),
#   ('green', 1),
#   ('qkd', 1),
#   ('level', 1),
#   ('public audit', 1),
#   ('scheme', 1),
#   ('pvcs', 1),
#   ('mle', 1),
#   ('speck', 1),
#   ('mask', 1),
#   ('templat', 1),
#   ('mtg', 1),
#   ('key agreement', 1),
#   ('exponenti synchron', 1),
#   ('xvcs', 1),
#   ('nussbaum', 1),
#   ('grid', 1),
#   ('qnsc', 1),
#   ('random forest', 1),
#   ('constrain devic', 1),
#   ('sdn', 1),
#   ('trait', 1),
#   ('storag', 1),
#   ('app', 1),
#   ('retriev', 1),
#   ('analyz base', 1),
#   ('gf', 1),
#   ('msqkd', 1),
#   ('ntru', 1),
#   ('channel attack', 1),
#   ('ntt', 1),
#   ('parti', 1),
#   ('commit scheme', 1),
#   ('client sid', 1),
#   ('radix', 1),
#   ('audit', 1),
#   ('social media', 1),
#   ('cluster', 1),
#   ('type attack', 1),
#   ('transmitt', 1),
#   ('subag', 1),
#   ('file', 1),
#   ('ln', 1),
#   ('prf', 1),
#   ('gnss', 1),
#   ('role', 1),
#   ('imag encrypt', 1),
#   ('cryptographi', 1),
#   ('domain recommend', 1),
#   ('sn', 1),
#   ('secret', 1),
#   ('compress', 1),
#   ('messag bit', 1),
#   ('ikc', 1),
#   ('tea', 1),
#   ('tls', 1),
#   ('map techniqu', 1),
#   ('2d ccm', 1),
#   ('obfusc', 1),
#   ('dispers', 1),
#   ('lsb', 1),
#   ('rdic', 1),
#   ('ciphertext', 1),
#   ('multimedia', 1),
#   ('fog', 1),
#   ('random', 1),
#   ('qss', 1),
#   ('tasti', 1),
#   ('key exchang', 1),
#   ('symmetr', 1),
#   ('scalar multipl', 1)],
#  2: [('crack', 5),
#   ('vehicl', 4),
#   ('ai', 3),
#   ('plant', 3),
#   ('track', 3),
#   ('displac', 3),
#   ('filter', 3),
#   ('underwat', 3),
#   ('detect', 3),
#   ('anomali', 2),
#   ('instrument', 2),
#   ('salient', 2),
#   ('compress', 2),
#   ('ethic', 2),
#   ('style', 2),
#   ('structur health', 2),
#   ('vibrat', 2),
#   ('tea', 2),
#   ('predict', 2),
#   ('wast', 2),
#   ('caption', 2),
#   ('action', 2),
#   ('tire', 2),
#   ('calibr', 2),
#   ('eye', 2),
#   ('ship', 2),
#   ('pig', 2),
#   ('yolov3', 2),
#   ('modal', 2),
#   ('color', 2),
#   ('segment', 2),
#   ('region', 2),
#   ('imag', 2),
#   ('fractur', 2),
#   ('annot', 2),
#   ('orchard', 2),
#   ('inspect', 2),
#   ('drone', 2),
#   ('phase', 2),
#   ('fruit', 2),
#   ('thermal', 2),
#   ('person', 1),
#   ('masonri', 1),
#   ('track algorithm', 1),
#   ('orm', 1),
#   ('pal', 1),
#   ('student', 1),
#   ('rail', 1),
#   ('microgripp', 1),
#   ('3d object', 1),
#   ('followupar', 1),
#   ('histor build', 1),
#   ('behaviour', 1),
#   ('ui', 1),
#   ('expect return', 1),
#   ('anticip', 1),
#   ('grasp', 1),
#   ('children', 1),
#   ('cardiac', 1),
#   ('poissonian', 1),
#   ('flock', 1),
#   ('urban', 1),
#   ('advertis', 1),
#   ('aesthet', 1),
#   ('alloy', 1),
#   ('hand', 1),
#   ('finit field', 1),
#   ('meteorolog', 1),
#   ('photometr stereo', 1),
#   ('smart citi', 1),
#   ('rotor', 1),
#   ('ring', 1),
#   ('curios', 1),
#   ('rover', 1),
#   ('equip', 1),
#   ('coal', 1),
#   ('pet', 1),
#   ('mask', 1),
#   ('best tourist', 1),
#   ('intrud', 1),
#   ('pain', 1),
#   ('fuzzi', 1),
#   ('spread', 1),
#   ('dairi', 1),
#   ('social distanc', 1),
#   ('tenodesi', 1),
#   ('foot traffic', 1),
#   ('log', 1),
#   ('slot', 1),
#   ('crane', 1),
#   ('box', 1),
#   ('fiduci', 1),
#   ('domain adapt', 1),
#   ('map elit', 1),
#   ('blockchain', 1),
#   ('stop', 1),
#   ('autortnet', 1),
#   ('landscap', 1),
#   ('cis', 1),
#   ('meat', 1),
#   ('prostat', 1),
#   ('corrupt', 1),
#   ('street view', 1),
#   ('pond', 1),
#   ('bound', 1),
#   ('biopharmaceut', 1),
#   ('trajectori', 1),
#   ('inform softwar', 1),
#   ('id', 1),
#   ('genom', 1),
#   ('occup inform', 1),
#   ('fft', 1),
#   ('elegan', 1),
#   ('dose', 1),
#   ('roof', 1),
#   ('sift', 1),
#   ('hors', 1),
#   ('vcr', 1),
#   ('glulam', 1),
#   ('siames', 1),
#   ('eye health', 1),
#   ('radiologist', 1),
#   ('appl', 1),
#   ('group activ', 1),
#   ('data set', 1),
#   ('anomali detect', 1),
#   ('railroad bridg', 1),
#   ('superpixel', 1),
#   ('depth data', 1),
#   ('flame', 1),
#   ('suicid', 1),
#   ('object detect', 1),
#   ('human activ', 1),
#   ('dehaz', 1),
#   ('cattl', 1),
#   ('older', 1),
#   ('wca', 1),
#   ('surveil', 1),
#   ('fault', 1),
#   ('didson', 1),
#   ('progress monitor', 1),
#   ('divers', 1),
#   ('batteri', 1),
#   ('primal', 1),
#   ('street', 1),
#   ('carcass', 1),
#   ('vqa', 1),
#   ('tensor', 1),
#   ('visual local', 1),
#   ('flat', 1),
#   ('bm25', 1),
#   ('shoot', 1),
#   ('prune', 1),
#   ('correl filter', 1),
#   ('underwat imag', 1),
#   ('microplast', 1),
#   ('cultur', 1),
#   ('aid analysi', 1),
#   ('cloth', 1),
#   ('align', 1),
#   ('confid score', 1),
#   ('pit', 1),
#   ('stiff', 1),
#   ('fast mov', 1),
#   ('exercis', 1),
#   ('navig', 1),
#   ('intrus detect', 1),
#   ('attribut', 1),
#   ('grid map', 1),
#   ('facial', 1),
#   ('traffic', 1),
#   ('digit terrain', 1),
#   ('cyber', 1),
#   ('excav', 1),
#   ('partit strategi', 1),
#   ('visual inform', 1),
#   ('sudoku', 1),
#   ('occlus', 1),
#   ('event camera', 1),
#   ('group', 1),
#   ('fatigu crack', 1),
#   ('don', 1),
#   ('aquada', 1),
#   ('landslid', 1),
#   ('imag featur', 1),
#   ('traffic sign', 1),
#   ('dataset size', 1),
#   ('scan method', 1),
#   ('video', 1),
#   ('optan', 1),
#   ('gan', 1),
#   ('home', 1),
#   ('wrgpruner', 1),
#   ('car', 1),
#   ('poultri', 1),
#   ('vpr', 1),
#   ('rescu rout', 1),
#   ('depth estim', 1),
#   ('panel', 1),
#   ('consum interact', 1),
#   ('blurri', 1),
#   ('surfac', 1),
#   ('contact trace', 1),
#   ('sot', 1),
#   ('green', 1),
#   ('util pole', 1),
#   ('subspac', 1),
#   ('maf', 1),
#   ('attent', 1),
#   ('broccoli', 1),
#   ('stixel', 1),
#   ('monitor', 1),
#   ('pmz', 1),
#   ('skill', 1),
#   ('anthropometri', 1),
#   ('util network', 1),
#   ('carrot', 1),
#   ('logic core', 1),
#   ('multiscal', 1),
#   ('sort', 1),
#   ('fluoroscopi', 1),
#   ('small object', 1),
#   ('linear complex', 1),
#   ('iiot', 1),
#   ('pm2', 1),
#   ('fer', 1),
#   ('ftl', 1),
#   ('cbir', 1),
#   ('grammar', 1),
#   ('popul', 1),
#   ('radiolog', 1),
#   ('edg awar', 1),
#   ('hyperion', 1),
#   ('manufactur', 1),
#   ('head mount', 1),
#   ('ndas', 1),
#   ('visual', 1),
#   ('imp', 1),
#   ('diabet', 1),
#   ('driver', 1),
#   ('express recognit', 1),
#   ('electr', 1),
#   ('wild', 1),
#   ('bas class', 1),
#   ('visual attent', 1),
#   ('gestur', 1),
#   ('daylight', 1),
#   ('summar', 1),
#   ('crowd count', 1),
#   ('chaogat', 1),
#   ('autoencod', 1),
#   ('label', 1),
#   ('follicular', 1),
#   ('sensori', 1),
#   ('constant tim', 1),
#   ('measur scenario', 1),
#   ('quasi subfield', 1),
#   ('adversari', 1),
#   ('unsupervis machin', 1),
#   ('forecast', 1),
#   ('mleasac', 1),
#   ('arianna', 1),
#   ('fpga', 1),
#   ('heat haze', 1),
#   ('cnn', 1),
#   ('poros', 1),
#   ('goal', 1),
#   ('park', 1),
#   ('damag', 1),
#   ('option paramet', 1),
#   ('sampl', 1),
#   ('ns', 1),
#   ('supersql', 1),
#   ('descriptor', 1),
#   ('2018', 1),
#   ('gnss', 1),
#   ('memrist', 1),
#   ('msis', 1),
#   ('sonif', 1),
#   ('roadway', 1),
#   ('foam', 1),
#   ('diagnost test', 1),
#   ('clwe', 1),
#   ('potato', 1),
#   ('f2n', 1),
#   ('ferment', 1),
#   ('defect', 1),
#   ('bind', 1),
#   ('marker', 1),
#   ('uav', 1),
#   ('coronavirus', 1),
#   ('fit', 1),
#   ('stone', 1),
#   ('shape sens', 1),
#   ('weed', 1),
#   ('sonographi', 1),
#   ('strategi', 1),
#   ('geodes', 1),
#   ('transfer learn', 1),
#   ('classif', 1),
#   ('echo', 1),
#   ('light', 1),
#   ('encount', 1),
#   ('sport', 1),
#   ('tag', 1),
#   ('land size', 1),
#   ('conic', 1),
#   ('surfac defect', 1),
#   ('product', 1),
#   ('anpr', 1),
#   ('gse', 1),
#   ('scale spati', 1),
#   ('heat', 1),
#   ('rfid', 1),
#   ('base food', 1),
#   ('cnc', 1),
#   ('point cloud', 1),
#   ('question', 1),
#   ('tree', 1),
#   ('syntact', 1),
#   ('neurorobot', 1),
#   ('term memori', 1),
#   ('synthesi', 1),
#   ('signal time', 1),
#   ('record', 1),
#   ('element list', 1),
#   ('solar', 1),
#   ('stereo', 1),
#   ('boolean function', 1),
#   ('drowsi', 1),
#   ('pedestrian', 1),
#   ('engin structur', 1),
#   ('idl', 1),
#   ('test set', 1),
#   ('affin', 1),
#   ('safeti', 1),
#   ('ekf', 1),
#   ('csgan', 1),
#   ('comput vision', 1),
#   ('diet', 1),
#   ('led', 1),
#   ('spoof', 1),
#   ('breast', 1),
#   ('geowin', 1),
#   ('radio', 1),
#   ('monoton', 1),
#   ('poct', 1),
#   ('edg ai', 1),
#   ('onlin shop', 1),
#   ('countermeasur', 1),
#   ('strip', 1),
#   ('custom mad', 1),
#   ('obstacl detect', 1),
#   ('cook', 1),
#   ('workflow process', 1),
#   ('candidemia', 1),
#   ('anomal', 1),
#   ('pedestrian detect', 1),
#   ('kg', 1),
#   ('farm', 1),
#   ('cubesat', 1),
#   ('congruenc', 1),
#   ('phenotyp', 1),
#   ('bat', 1),
#   ('tupl', 1),
#   ('glaze', 1),
#   ('contractor', 1),
#   ('movement', 1),
#   ('3d detect', 1),
#   ('analyt redund', 1),
#   ('cytolog', 1),
#   ('queue', 1),
#   ('visual privaci', 1),
#   ('distanc', 1),
#   ('lake', 1),
#   ('sleep', 1),
#   ('inpaint', 1),
#   ('transplant', 1),
#   ('flow', 1),
#   ('multi scal', 1),
#   ('work cycl', 1),
#   ('categor data', 1),
#   ('background featur', 1),
#   ('correspond', 1),
#   ('object track', 1),
#   ('web scrape', 1),
#   ('gaze', 1),
#   ('water', 1),
#   ('surgic', 1),
#   ('spacecraft', 1),
#   ('reconstruct', 1),
#   ('tbd', 1),
#   ('puzzl', 1),
#   ('commerc', 1),
#   ('oliv', 1),
#   ('fog', 1),
#   ('processar', 1),
#   ('vessel', 1),
#   ('specchio', 1),
#   ('aqi', 1),
#   ('multimod imag', 1),
#   ('face', 1),
#   ('heritag', 1),
#   ('wstl', 1),
#   ('depth', 1),
#   ('acupunctur', 1),
#   ('jam', 1),
#   ('teacher', 1),
#   ('rater', 1),
#   ('wheat', 1),
#   ('micromotor', 1),
#   ('diseas', 1),
#   ('creatinin', 1),
#   ('calcium', 1)],
#  3: [('ontolog', 11),
#   ('databas', 6),
#   ('watermark', 5),
#   ('queri', 4),
#   ('fuzzi', 3),
#   ('sql', 3),
#   ('normal', 2),
#   ('nosql', 2),
#   ('blockchain', 2),
#   ('genom', 2),
#   ('big data', 2),
#   ('graph databas', 2),
#   ('index', 2),
#   ('specul', 2),
#   ('keyword', 2),
#   ('xml', 2),
#   ('semant web', 2),
#   ('viewpoint', 1),
#   ('clinic trial', 1),
#   ('port graph', 1),
#   ('queri write', 1),
#   ('data valu', 1),
#   ('pest', 1),
#   ('workload', 1),
#   ('object rel', 1),
#   ('similar patient', 1),
#   ('depend', 1),
#   ('interv', 1),
#   ('normal form', 1),
#   ('educ cloud', 1),
#   ('remot sens', 1),
#   ('pma', 1),
#   ('data exchang', 1),
#   ('increas popular', 1),
#   ('apach', 1),
#   ('geolog', 1),
#   ('preserv', 1),
#   ('map rule', 1),
#   ('relat tree', 1),
#   ('connect compon', 1),
#   ('forecast', 1),
#   ('statut', 1),
#   ('spl', 1),
#   ('healthcar', 1),
#   ('citus', 1),
#   ('cluster', 1),
#   ('hadoop', 1),
#   ('client', 1),
#   ('orm', 1),
#   ('synchron', 1),
#   ('monad', 1),
#   ('bitcoin', 1),
#   ('mongodb', 1),
#   ('rdf', 1),
#   ('multidatabas', 1),
#   ('document', 1),
#   ('diseas', 1),
#   ('crop', 1),
#   ('tenant', 1),
#   ('opc', 1),
#   ('log', 1),
#   ('metal', 1),
#   ('valuerank', 1),
#   ('ei', 1),
#   ('relational bas', 1),
#   ('schema instanc', 1),
#   ('pbee', 1),
#   ('student', 1),
#   ('word embed', 1),
#   ('language', 1),
#   ('redbul', 1),
#   ('hierarch data', 1),
#   ('null', 1),
#   ('qep', 1),
#   ('tool', 1),
#   ('answer', 1),
#   ('dbms', 1),
#   ('shine', 1),
#   ('block', 1),
#   ('mapreduc', 1),
#   ('normalis', 1),
#   ('featur model', 1),
#   ('refactor', 1),
#   ('data consolid', 1),
#   ('candid key', 1),
#   ('languag process', 1),
#   ('search', 1),
#   ('spreadsheet', 1),
#   ('astronom', 1),
#   ('relat graph', 1),
#   ('energi', 1),
#   ('case bas', 1),
#   ('ehr', 1),
#   ('eer model', 1),
#   ('app', 1),
#   ('cach', 1),
#   ('sketch', 1),
#   ('graph', 1),
#   ('roi', 1),
#   ('databas structur', 1),
#   ('meta model', 1),
#   ('bas modul', 1),
#   ('remot', 1),
#   ('candid network', 1),
#   ('crowdsourc', 1),
#   ('bim', 1),
#   ('ml', 1),
#   ('context', 1),
#   ('hbase', 1),
#   ('tim databas', 1),
#   ('conflat', 1),
#   ('web applic', 1),
#   ('subject area', 1),
#   ('shuffl', 1),
#   ('artifact', 1),
#   ('multi rel', 1),
#   ('block devic', 1),
#   ('schema', 1),
#   ('hypergraph', 1),
#   ('cultiv land', 1),
#   ('tamper', 1),
#   ('atj', 1),
#   ('multi synchron', 1),
#   ('model', 1),
#   ('fragment', 1),
#   ('json', 1),
#   ('ifc', 1),
#   ('data retriev', 1),
#   ('fingerprint', 1),
#   ('covid', 1),
#   ('databas program', 1),
#   ('flight', 1),
#   ('cohort', 1),
#   ('trace', 1),
#   ('relat data', 1),
#   ('event', 1),
#   ('proven', 1)]}

# %%
original_data
# Out:
#         class                                              title  \
# id
# id1         1  Anomaly detection in wide area imagery [Geniş ...
# id2         1  Person re-identification with deep kronecker-p...
# id3         1    Crack detection in images of masonry using cnns
# id4         5  Towards an energy efficient code generator for...
# id5         5  Sub-polyhedral scheduling using (Unit-)two-var...
# ...       ...                                                ...
# id1328      1  Colorimetric point-of-care paper-based sensors...
# id1329      1  Calcium identification and scoring based on ec...
# id1330      1  Considering filter importance and irreplaceabi...
# id1331      4  Low-complexity bit-serial sequential polynomia...
# id1332      5  Preventing reverse engineering threat in java ...
#
#                                                  abstract
# id
# id1     This study is about detecting anomalies in wid...
# id2     Person re-identification (re-ID) aims to robus...
# id3     While there is a significant body of research ...
# id4     Using a smartphone become the part of our ever...
# id5     Polyhedral compilation has been successful in ...
# ...                                                   ...
# id1328  Creatinine is a clinically significant analyte...
# id1329  Currently, an echocardiography expert is neede...
# id1330  Deep convolutional neural network (CNNs) have ...
# id1331  GF(2m) multiplication is a complex and perform...
# id1332  Java programs are compiled into a platform ind...
#
# [1332 rows x 3 columns]
